# %% [markdown]
# <a href="https://colab.research.google.com/github/andresfelipe880/ModelosAnaliticos2026-07/blob/main/Librerias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Librerias

# %% [markdown]
# Crea un programa que verifique si una persona es mayor de edad. Una persona es considerada mayor de edad si tiene 18 años o más.

# %%
#Paso 1 instalar librerias

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas as pd

# Paso 2. Cargar set de datos

dataset=pd.read_excel("/content/Salary_Data.xlsx")
dataset
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
#Paso 3 analisis exploration de datos
dataset.head(3)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731

# %%
dataset.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
#Paso 4 separacion de los valores
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872])

# %%
#5 separacion del dataset de entrenamiento y prueba

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

# %%
#6 Entrenamiento del modelo de regresion lineal
from sklearn.linear_model import LinearRegression
regresion = LinearRegression()
regresion.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#paso7: prediccion datos de prueba
y_pred = regresion.predict(X_test)

# %%
#paso 8 grafica de resultados de entrenamiento
plt.scatter(X_train, y_train, color = 'red')
plt.scatter(X_train, regresion.predict (X_train), color = 'blue')
plt.title('salario vs experiencia (set de entrenamiento)')
plt.xlabel('años de experiencia')
plt.ylabel('salario')
plt.show()

# %%
#paso 9: grafica de resultados de prueba
plt.scatter(X_test, y_test, color = 'red')
plt.scatter(X_test, y_pred, color = 'blue')
plt.title('salario vs experiencia (set de prueba)')
plt.xlabel('años de experiencia')
plt.ylabel('salario')
plt.show()
