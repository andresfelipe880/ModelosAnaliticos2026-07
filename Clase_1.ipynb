# %% [markdown]
# <a href="https://colab.research.google.com/github/andresfelipe880/ModelosAnaliticos2026-07/blob/main/Clase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INTRODUCCION A PYTHON**
#
# MODELOS ANALITICOS
#
# UNICAFAM
#
# DOCENTE:NICOLAS MOJICA
#
# ESTUDIANTE: ANDRES FELIPE PEÑA ALVARADO

# %% [markdown]
# ## COMENTARIOS DE CODIGOS

# %%
#ESTE ES UN COMENTARIO DE UNA SOLA LINEA
print ("hola mundo")
# Out:
# hola mundo

# %%
'''
este
es
un comentario
de varias lineas
'''
# Out:
# '\neste\nes\nun comentario\nde varias lineas\n'

# %% [markdown]
# ##VARIABLE

# %%
var="hola mundo"
print(var)
# Out:
# hola mundo

# %%
#1. LAS VARIABLES DEBEN SER EN MINUSCULA
#2. LAS VARIABLES NO DEBEN TENER ESPACIOS
#3. LAS VARIABLES NO DEBEN CONTENER CARACTERES ESPECIALES

# %% [markdown]
# ## TIPOS DE DATOS

# %%
# ENTERO
entero=5
entero_explicito=int(5)

#DECIMALES
decimal=5.0
decimal_explicito=float(5.0)

# %%
type(entero)
# Out:
# int

# %% [markdown]
# ## OPERADORES ARITMETICOS

# %%
a=10
b=5
c=a+b
print(a+b)
print(c)
# Out:
# 15
# 15

# %%
#DIVISION ENTERA
print(a//b)
# Out:
# 2

# %%
# MODULO
print(a%b)
# Out:
# 0

# %%
# EXPONENCIACION
print(b**2)
# Out:
# 25

# %%
# ASIGNACION COMPUESTA
b+=2
print(b)
# Out:
# 9

# %% [markdown]
# ##TEXTO

# %%
cadena="python es genial"
print(cadena[5])
# Out:
# n

# %%
# EXTRAER LA PALABRA PYTHON
print(cadena[0:6])
# Out:
# python

# %%
# EXTRAER LA PALABRA PYTHON
print(cadena[0:18])
# Out:
# python es genial

# %%
# EXTRAER LA PALABRA GENIAL
print(cadena[10:17])
# Out:
# genial

# %%
# CONCATENACION DE VALORES
palabra1="hola"
palabra2="mundo"
print(palabra1+" , "+palabra2)
# Out:
# hola , mundo

# %%
# CAMBIOS DE FORMATOS
print(cadena.upper())
# Out:
# PYTHON ES GENIAL

# %%
# CAMBIOS DE FORMATO
print(cadena.lower())
# Out:
# python es genial
